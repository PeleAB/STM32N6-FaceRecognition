# %% [markdown]
# # Model to STM32 Conversion using ST Edge AI
#
# This notebook demonstrates how to convert machine learning models to STM32-compatible code using ST Edge AI tools.
#
# We'll convert:
# 1. CenterFace TFLite model for face detection
# 2. MobileFaceNet ONNX model for face recognition

# %% [markdown]
# ## Setup and Dependencies

# %%
import os
import subprocess
import json
from pathlib import Path

# Use STM32CubeMX version that works (v2.1.0 instead of v2.2.0)
STEDGEAI_PATH = '/home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai'

# Test if stedgeai is accessible at the STM32CubeMX path
if os.path.exists(STEDGEAI_PATH):
    print(f"✅ stedgeai found at: {STEDGEAI_PATH}")
    
    # Test if it's executable and check for AVX requirements
    try:
        result = subprocess.run([STEDGEAI_PATH, '--help'], capture_output=True, text=True, timeout=5)
        print("✅ stedgeai is executable and responding")
        # Check version
        if 'v2.1.0' in result.stdout:
            print("✅ Using STM32CubeMX compatible version (v2.1.0)")
        else:
            print("ℹ️  Version info not found in help output")
    except (subprocess.CalledProcessError, subprocess.TimeoutExpired) as e:
        print(f"⚠️  stedgeai found but may have issues: {e}")
    except Exception as e:
        if "AVX" in str(e) or "SIGILL" in str(e):
            print("❌ AVX instruction set not available - this is likely the issue")
            print("Solutions:")
            print("1. Enable AVX in VM settings (see instructions)")
            print("2. Use a different machine with AVX support")
            print("3. Try running stedgeai with compatibility flags")
else:
    print(f"❌ stedgeai not found at: {STEDGEAI_PATH}")
    print("Please verify the installation path")

# Check CPU capabilities
print("\n=== CPU Capabilities Check ===")
try:
    result = subprocess.run(['lscpu'], capture_output=True, text=True)
    cpu_info = result.stdout
    if 'avx' in cpu_info.lower():
        print("✅ AVX support detected")
    else:
        print("❌ No AVX support detected")
        print("This VM needs AVX enabled in hypervisor settings")
except:
    print("Could not check CPU capabilities")

# Set up paths
models_dir = Path('./models')
output_dir = Path('./stm32_output')
output_dir.mkdir(exist_ok=True)

# Model paths
centerface_model = models_dir / 'centerface.tflite'
mobilefacenet_model = models_dir / 'mobilefacenet_real_faces_onnx.onnx'

print(f"CenterFace model exists: {centerface_model.exists()}")
print(f"MobileFaceNet model exists: {mobilefacenet_model.exists()}")
# Out:
# ✅ stedgeai found at: /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai
# ✅ stedgeai is executable and responding
# ✅ Using STM32CubeMX compatible version (v2.1.0)
#
# === CPU Capabilities Check ===
# ✅ AVX support detected
# CenterFace model exists: True
# MobileFaceNet model exists: True

# %% [markdown]
# ## Configuration for ST Edge AI
#
# Create configuration files for optimized STM32 generation

# %% [markdown]
# ## Memory Layout Strategy
#
# The two models use different memory pool configurations to avoid conflicts in external flash:
#
# **Memory Pool Assignments:**
# - **CenterFace (model1.mpool)**: External flash starts at `0x71000000` (Face Detection)
# - **MobileFaceNet (model2.mpool)**: External flash starts at `0x72000000` (Face Recognition)
#
#
# **Flash Memory Layout:**
# ```
# 0x70000000 - 0x700FFFFF: Bootloader code (1MB)
# 0x70100000 - 0x709FFFFF: Application code (8MB)
# 0x70A00000 - 0x70FFFFFF: Reserved space (6MB)
# 0x71000000 - 0x71FFFFFF: Face Detection model data (16MB)
# 0x72000000 - 0x72FFFFFF: Face Recognition model data (16MB)
# 0x73000000 - 0x74FFFFFF: Available for other uses (32MB)
# ```
#
# This layout ensures:
# - No model data overwrites the bootloader or application
# - Both models can coexist without conflicts
# - Efficient memory utilization on STM32N6 with external flash"

# %%
# Create neural art configuration for face detection (CenterFace)
# Uses model1.mpool with external flash at 0x71000000
face_detection_config = {
    "Globals": {},
    "Profiles": {
        "centerface": {
            "memory_pool": "./mempools/model1.mpool",
            "options": "-O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller"
        }
    }
}

# Create neural art configuration for face recognition (MobileFaceNet)
# Uses model2.mpool with external flash at 0x72000000
face_recognition_config = {
    "Globals": {},
    "Profiles": {
        "mobilefacenet": {
            "memory_pool": "./mempools/model2.mpool",
            "options": "-O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller"
        }
    }
}

# Save configurations
with open('face_detection_config.json', 'w') as f:
    json.dump(face_detection_config, f, indent=4)

with open('face_recognition_config.json', 'w') as f:
    json.dump(face_recognition_config, f, indent=4)

print("Configuration files created with proper memory pool assignments:")
print("- CenterFace (Face Detection): model1.mpool (external flash @ 0x71000000)")
print("- MobileFaceNet (Face Recognition): model2.mpool (external flash @ 0x72000000)")
# Out:
# Configuration files created with proper memory pool assignments:
# - CenterFace (Face Detection): model1.mpool (external flash @ 0x71000000)
# - MobileFaceNet (Face Recognition): model2.mpool (external flash @ 0x72000000)

# %% [markdown]
# ## Convert CenterFace TFLite Model

# %%
def run_stedgeai_conversion(model_path, output_name, target="stm32n6", input_data_type="uint8", neural_art_config="", profile_config=""):
    """Run ST Edge AI conversion for a model using STM32CubeMX configuration"""
    
    # Use the explicit path defined earlier
    if not os.path.exists(STEDGEAI_PATH):
        print(f"Error: stedgeai not found at {STEDGEAI_PATH}")
        return False
    
    print(f"Using stedgeai from: {STEDGEAI_PATH}")
    
    
    cmd = [
        STEDGEAI_PATH, "generate",
        "--name", str(output_name),
        "--model", str(model_path),
        "--target", target,
        "--st-neural-art", f"{profile_config}@{neural_art_config}",
        "--input-data-type", input_data_type,
        "--output", str(output_dir / output_name)
    ]
    
    print(f"Running command: {' '.join(cmd)}")
    
    try:
        result = subprocess.run(cmd, capture_output=True, text=True, check=True)
        print("STDOUT:", result.stdout)
        if result.stderr:
            print("STDERR:", result.stderr)
        return True
    except subprocess.CalledProcessError as e:
        print(f"Error running stedgeai: {e}")
        print(f"STDOUT: {e.stdout}")
        print(f"STDERR: {e.stderr}")
        return False

# %%
# Convert CenterFace model
print("Converting CenterFace TFLite model...")
centerface_success = run_stedgeai_conversion(
    centerface_model, 
    'face_detection',
    target="stm32n6",
    input_data_type="float32",
    neural_art_config = "face_detection_config.json",
    profile_config = "centerface"
)

if centerface_success:
    print("✅ CenterFace model conversion completed successfully")
else:
    print("❌ CenterFace model conversion failed")
# Out:
# Converting CenterFace TFLite model...
# Using stedgeai from: /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai
# Running command: /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai generate --name face_detection --model models/centerface.tflite --target stm32n6 --st-neural-art centerface@face_detection_config.json --input-data-type float32 --output stm32_output/face_detection
# STDOUT: ST Edge AI Core v2.1.0-20194 329b0e98d
#
# PASS:   0%|          | 0/92 [00:00<?, ?it/s]
# PASS:  12%|█▏        | 11/92 [00:02<00:14,  5.49it/s]
# PASS:  13%|█▎        | 12/92 [00:02<00:14,  5.38it/s]
# PASS:  20%|█▉        | 18/92 [00:02<00:07,  9.47it/s]
# PASS:  23%|██▎       | 21/92 [00:02<00:06, 10.86it/s]
# PASS:  26%|██▌       | 24/92 [00:02<00:05, 13.12it/s]
# PASS:  29%|██▉       | 27/92 [00:02<00:04, 15.12it/s]
# PASS:  36%|███▌      | 33/92 [00:02<00:02, 22.63it/s]
# PASS:  40%|████      | 37/92 [00:03<00:02, 23.53it/s]
# PASS:  45%|████▍     | 41/92 [00:03<00:02, 24.29it/s]
# PASS:  49%|████▉     | 45/92 [00:03<00:01, 24.80it/s]
# PASS:  52%|█████▏    | 48/92 [00:03<00:01, 24.99it/s]
# PASS:  55%|█████▌    | 51/92 [00:03<00:01, 25.04it/s]
# PASS:  59%|█████▊    | 54/92 [00:03<00:01, 24.79it/s]
# PASS:  64%|██████▍   | 59/92 [00:03<00:01, 27.43it/s]
# PASS:  67%|██████▋   | 62/92 [00:03<00:01, 28.00it/s]
# PASS:  71%|███████   | 65/92 [00:04<00:01, 26.82it/s]
# PASS:  74%|███████▍  | 68/92 [00:04<00:00, 26.06it/s]
# PASS:  77%|███████▋  | 71/92 [00:04<00:00, 23.05it/s]
# PASS:  82%|████████▏ | 75/92 [00:04<00:00, 25.45it/s]
# PASS:  86%|████████▌ | 79/92 [00:04<00:00, 27.46it/s]
# PASS:  89%|████████▉ | 82/92 [00:04<00:00, 26.42it/s]
#
#  >>>> EXECUTING NEURAL ART COMPILER
#
# PASS:  89%|████████▉ | 82/92 [00:05<00:00, 26.42it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/atonn -i "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0.onnx" --json-quant-file "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0_Q.json" -g "face_detection.c" --load-mdesc "/home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/configs/stm32n6.mdesc" --load-mpool "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/mempools/model1.mpool" --save-mpool-file "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_detection/model1.mpool" --out-dir-prefix "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_detection/" -O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller --output-info-file "c_info.json" --network-name "face_detection"
#
# PASS:  89%|████████▉ | 82/92 [00:05<00:00, 26.42it/s]
#
#  <<<< DONE EXECUTING NEURAL ART COMPILER
#
# PASS:  89%|████████▉ | 82/92 [00:06<00:00, 26.42it/s]
# PASS:  92%|█████████▏| 85/92 [00:06<00:01,  5.13it/s]
#
#  >>>> EXECUTING EPOCH_CONTROLLER POST_PROCESSING
#
# PASS:  92%|█████████▏| 85/92 [00:06<00:01,  5.13it/s]
#
#  <<<< DONE EXECUTING EPOCH_CONTROLLER POST_PROCESSING
#
# PASS:  92%|█████████▏| 85/92 [00:07<00:01,  5.13it/s]
# PASS:  95%|█████████▍| 87/92 [00:07<00:01,  3.37it/s]
#
#
#  Exec/report summary (generate)
#  ----------------------------------------------------------------------------------------------------------------
#  model file         :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/models/centerface.tflite
#  type               :   tflite
#  c_name             :   face_detection
#  options            :   allocate-inputs, allocate-outputs
#  optimization       :   balanced
#  target/series      :   stm32n6npu
#  workspace dir      :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws
#  output dir         :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection
#  model_fmt          :   us/sa per tensor
#  model_name         :   centerface
#  model_hash         :   0x8012b2664fad6746555159ab8820d9b8
#  params #           :   1,819,927 items (1.78 MiB)
#  ----------------------------------------------------------------------------------------------------------------
#  input 1/1          :   'Input_0_out_0', f32(1x3x128x128), 192.00 KBytes, activations
#  output 1/4         :   'Transpose_290_out_0', f32(1x32x32x2), 8.00 KBytes, activations
#  output 2/4         :   'Transpose_282_out_0', f32(1x32x32x10), 40.00 KBytes, activations
#  output 3/4         :   'Transpose_297_out_0', f32(1x32x32x1), 4.00 KBytes, activations
#  output 4/4         :   'Transpose_286_out_0', f32(1x32x32x2), 8.00 KBytes, activations
#  outputs (total)    :   0 Bytes
#  macc               :   0
#  weights (ro)       :   2,455,425 B (2.34 MiB) (1 segment) / -4,824,283(-66.3%) vs float model
#  activations (rw)   :   491,520 B (480.00 KiB) (2 segments) *
#  ram (total)        :   491,520 B (480.00 KiB) = 491,520 + 0 + 0
#  ----------------------------------------------------------------------------------------------------------------
#  (*) 'input'/'output' buffers can be used from the activations buffer
#
# PASS:  95%|█████████▍| 87/92 [00:08<00:01,  3.37it/s]
#
# Computing AI RT data/code size (target=stm32n6npu)..
#
# PASS:  95%|█████████▍| 87/92 [00:08<00:01,  3.37it/s]
#
#    >>> Shell execution has FAILED (returned code = 1)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    $ arm-none-eabi-gcc -mthumb -mcpu=cortex-m55 -mtune=cortex-m55 -mfloat-abi=hard -Wall -Wextra -Wundef -Wstrict-prototypes -g3 -gdwarf-3 -fmessage-length=0 -fsigned-char -ffunction-sections -fdata-sections -fomit-frame-pointer -falign-functions=16 -Os -DUSE_FULL_LL_DRIVER -DLL_ATON_PLATFORM=LL_ATON_PLAT_SWEMUL -DLL_ATON_OSAL=LL_ATON_OSAL_BARE_METAL -DLL_ATON_RT_MODE=LL_ATON_RT_POLLING -DLL_ATON_SW_FALLBACK -I /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Inc -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/Devices/STM32N6XX -c /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    In file included from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_platform.h:378,
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#                     from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton.h:36,
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#                     from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:27:
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/Devices/STM32N6XX/ATON.h:6771:2: warning: #warning "Using default value of ATON_BASE" [-Wcpp]
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#     6771 | #warning "Using default value of ATON_BASE"
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |  ^~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    In file included from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:25:
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c: In function '__LL_ATON_RT_IrqErr':
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:776:20: warning: format '%u' expects argument of type 'unsigned int', but argument 2 has type 'uint32_t' {aka 'long unsigned int'} [-Wformat=]
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      776 |     LL_ATON_PRINTF("Streaming engine #%u error interrupt: 0x%" PRIx32 "\n", streaming_engine_nr, streng_err);
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~              ~~~~~~~~~~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                                             |
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                                             uint32_t {aka long unsigned int}
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:776:40: note: format string is defined here
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      776 |     LL_ATON_PRINTF("Streaming engine #%u error interrupt: 0x%" PRIx32 "\n", streaming_engine_nr, streng_err);
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                       ~^
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                        |
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                        unsigned int
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                       %lu
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:75: error: expected ')' before 'PRIx64'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                                           ^~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:29:1: note: 'PRIx64' is defined in header '<inttypes.h>'; did you forget to '#include <inttypes.h>'?
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       28 | #include "ll_aton_runtime.h"
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      +++ |+#include <inttypes.h>
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       29 |
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:35: note: to match this '('
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                   ^
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:23: note: in expansion of macro 'LL_ATON_PRINTF'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                       ^~~~~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:38: warning: format '%d' expects a matching 'int' argument [-Wformat=]
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:62: note: format string is defined here
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                             ~^
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                              |
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                              int
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:38: warning: spurious trailing '%' in format [-Wformat=]
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:72: note: format string is defined here
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#          |                                                                        ^
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
#
#    <<<
#
# PASS:  95%|█████████▍| 87/92 [00:12<00:01,  3.37it/s]
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Compilation details
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Compiler version: 1.1.0-31
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Compiler arguments:  -i /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0.onnx --json-quant-file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0_Q.json -g face_detection.c --load-mdesc /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/configs/stm32n6.mdesc --load-mpool /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/mempools/model1.mpool --save-mpool-file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_detection/model1.mpool --out-dir-prefix /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_detection/ -O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller --output-info-file c_info.json --network-name face_detection
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Memory usage information  (input/output buffers are included in activations)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	flexMEM    [0x34000000 - 0x34000000]:          0  B /          0  B  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	cpuRAM1    [0x34080000 - 0x34080000]:          0  B /          0  B  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	cpuRAM2    [0x34100000 - 0x34200000]:          0  B /      1.000 MB  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM3    [0x34200000 - 0x34270000]:          0  B /    448.000 kB  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM4    [0x34270000 - 0x342E0000]:     96.000 kB /    448.000 kB  ( 21.43 % used) -- weights:          0  B (  0.00 % used)  activations:     96.000 kB ( 21.43 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM5    [0x342E0000 - 0x34350000]:    384.000 kB /    448.000 kB  ( 85.71 % used) -- weights:          0  B (  0.00 % used)  activations:    384.000 kB ( 85.71 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM6    [0x34350000 - 0x343C0000]:          0  B /    448.000 kB  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	octoFlash  [0x71000000 - 0x74D00000]:      2.342 MB /     61.000 MB  (  3.84 % used) -- weights:      2.342 MB (  3.84 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	hyperRAM   [0x90000000 - 0x91000000]:          0  B /     16.000 MB  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Total:                                             2.810 MB                                  -- weights:      2.342 MB                  activations:    480.000 kB
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Used memory ranges
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM4    [0x34270000 - 0x342E0000]: 0x34270000-0x34288000
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	npuRAM5    [0x342E0000 - 0x34350000]: 0x342E0000-0x34340000
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# 	octoFlash  [0x71000000 - 0x74D00000]: 0x71000000-0x71257790
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Epochs details
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Total number of epochs: 86 of which 10 implemented in software
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch ID   HW/SW/EC Operation (SW only)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 1       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 2      -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 3       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 4       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 5       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 6       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 7       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 8       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 9       EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 10      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 11      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 12      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 13      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 14      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 15      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 16      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 17      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 18      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 19      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 20      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 21      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 22      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 23      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 24      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 25      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 26      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 27      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 28      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 29      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 30      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 31      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 32      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 33      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 34      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 35      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 36      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 37      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 38      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 39      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 40      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 41      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 42      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 43      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 44      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 45      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 46      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 47      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 48      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 49      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 50      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 51      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 52      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 53      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 54      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 55      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 56      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 57      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 58      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 59      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 60      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 61      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 62     -SW-   (       Concat       )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 63     -SW-   (    DepthToSpace    )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 64      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 65      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 66      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 67     -SW-   (       Concat       )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 68     -SW-   (    DepthToSpace    )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 69      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 70      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 71      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 72     -SW-   (       Concat       )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 73     -SW-   (    DepthToSpace    )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 74      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 75      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 76      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 77      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 78      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 79     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 80      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 81     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 82      ??
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 83      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 84      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 85     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# epoch 86      EC
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  Generated files (6)
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  -------------------------------------------------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0.onnx
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/centerface_OE_3_2_0_Q.json
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/face_detection.c
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/face_detection_atonbuf.xSPI2.raw
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/face_detection.h
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/face_detection_ecblobs.h
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
#
# Creating txt report file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_detection/face_detection_generate_report.txt
#
# PASS:  97%|█████████▋| 89/92 [00:13<00:02,  1.24it/s]
# PASS:  99%|█████████▉| 91/92 [00:13<00:00,  1.56it/s]
# PASS: 100%|██████████| 92/92 [00:14<00:00,  1.42it/s]
#
# elapsed time (generate): 15.073s
#
# ✅ CenterFace model conversion completed successfully

# %% [markdown]
# ## Convert MobileFaceNet ONNX Model

# %%
# Convert MobileFaceNet model
print("Converting MobileFaceNet ONNX model...")
mobilefacenet_success = run_stedgeai_conversion(
    mobilefacenet_model, 
    'face_recognition',
    target="stm32n6",
    input_data_type="float32",
    neural_art_config = "face_recognition_config.json",
    profile_config = "mobilefacenet"
)

if mobilefacenet_success:
    print("✅ MobileFaceNet model conversion completed successfully")
else:
    print("❌ MobileFaceNet model conversion failed")
# Out:
# Converting MobileFaceNet ONNX model...
# Using stedgeai from: /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai
# Running command: /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/stedgeai generate --name face_recognition --model models/mobilefacenet_real_faces_onnx.onnx --target stm32n6 --st-neural-art mobilefacenet@face_recognition_config.json --input-data-type float32 --output stm32_output/face_recognition
# STDOUT: ST Edge AI Core v2.1.0-20194 329b0e98d
#
# PASS:   0%|          | 0/92 [00:00<?, ?it/s]
# PASS:  12%|█▏        | 11/92 [00:04<00:32,  2.50it/s]
# PASS:  18%|█▊        | 17/92 [00:04<00:19,  3.75it/s]
# PASS:  20%|█▉        | 18/92 [00:05<00:18,  3.96it/s]
# PASS:  22%|██▏       | 20/92 [00:07<00:32,  2.21it/s]
# PASS:  25%|██▌       | 23/92 [00:07<00:22,  3.09it/s]
# PASS:  29%|██▉       | 27/92 [00:07<00:13,  4.70it/s]
# PASS:  35%|███▍      | 32/92 [00:07<00:08,  7.03it/s]
# PASS:  38%|███▊      | 35/92 [00:08<00:07,  8.14it/s]
# PASS:  41%|████▏     | 38/92 [00:08<00:05,  9.74it/s]
# PASS:  45%|████▍     | 41/92 [00:08<00:04, 11.10it/s]
# PASS:  48%|████▊     | 44/92 [00:08<00:03, 12.64it/s]
# PASS:  51%|█████     | 47/92 [00:08<00:03, 14.39it/s]
# PASS:  54%|█████▍    | 50/92 [00:08<00:02, 15.40it/s]
# PASS:  57%|█████▋    | 52/92 [00:08<00:02, 15.28it/s]
# PASS:  63%|██████▎   | 58/92 [00:09<00:01, 21.61it/s]
# PASS:  66%|██████▋   | 61/92 [00:09<00:01, 22.71it/s]
# PASS:  70%|██████▉   | 64/92 [00:09<00:01, 20.63it/s]
# PASS:  73%|███████▎  | 67/92 [00:09<00:01, 20.44it/s]
# PASS:  76%|███████▌  | 70/92 [00:09<00:01, 20.75it/s]
# PASS:  80%|████████  | 74/92 [00:09<00:00, 22.66it/s]
# PASS:  85%|████████▍ | 78/92 [00:10<00:00, 24.51it/s]
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv1_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv2_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_23_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_23_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_0_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_0_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_1_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_1_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_2_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_2_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_3_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_3_model_model_3_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_34_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_34_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_0_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_0_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_1_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_1_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_2_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_2_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_3_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_3_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_4_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_4_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_5_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_4_model_model_5_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_45_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_45_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_5_model_model_0_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_5_model_model_0_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_5_model_model_1_conv_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_5_model_model_1_conv_dw_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: _conv_6_sep_prelu_PRelu_output_0 is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
#
# WARNING: output is not quantized
#
# PASS:  88%|████████▊ | 81/92 [00:10<00:00, 23.75it/s]
# PASS:  91%|█████████▏| 84/92 [00:11<00:00,  8.09it/s]
#
#  >>>> EXECUTING NEURAL ART COMPILER
#
# PASS:  91%|█████████▏| 84/92 [00:11<00:00,  8.09it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/linux/atonn -i "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0.onnx" --json-quant-file "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0_Q.json" -g "face_recognition.c" --load-mdesc "/home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/configs/stm32n6.mdesc" --load-mpool "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/mempools/model2.mpool" --save-mpool-file "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_recognition/model2.mpool" --out-dir-prefix "/home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_recognition/" -O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller --output-info-file "c_info.json" --network-name "face_recognition"
#
# PASS:  91%|█████████▏| 84/92 [00:11<00:00,  8.09it/s]
#
#  <<<< DONE EXECUTING NEURAL ART COMPILER
#
# PASS:  91%|█████████▏| 84/92 [00:11<00:00,  8.09it/s]
# PASS:  93%|█████████▎| 86/92 [00:12<00:01,  4.88it/s]
#
#  >>>> EXECUTING EPOCH_CONTROLLER POST_PROCESSING
#
# PASS:  93%|█████████▎| 86/92 [00:12<00:01,  4.88it/s]
#
#  <<<< DONE EXECUTING EPOCH_CONTROLLER POST_PROCESSING
#
# PASS:  93%|█████████▎| 86/92 [00:13<00:01,  4.88it/s]
#
#
#  Exec/report summary (generate)
#  ------------------------------------------------------------------------------------------------------------------------------
#  model file         :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/models/mobilefacenet_real_faces_onnx.onnx
#  type               :   onnx
#  c_name             :   face_recognition
#  options            :   allocate-inputs, allocate-outputs
#  optimization       :   balanced
#  target/series      :   stm32n6npu
#  workspace dir      :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws
#  output dir         :   /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition
#  model_fmt          :   ss/sa per tensor
#  model_name         :   mobilefacenet_real_faces_onnx
#  model_hash         :   0x37a5b97189de3272bf7e6fa09819f172
#  params #           :   993,600 items (1021.88 KiB)
#  ------------------------------------------------------------------------------------------------------------------------------
#  input 1/1          :   'Input_0_out_0', f32(1x3x112x112), 147.00 KBytes, activations
#  output 1/1         :   'BatchNormalization_289_out_0', f32(1x128), 512 Bytes, activations
#  macc               :   0
#  weights (ro)       :   1,242,529 B (1.18 MiB) (1 segment) / -2,731,871(-68.7%) vs float model
#  activations (rw)   :   4,116,480 B (3.93 MiB) (6 segments) *
#  ram (total)        :   4,116,480 B (3.93 MiB) = 4,116,480 + 0 + 0
#  ------------------------------------------------------------------------------------------------------------------------------
#  (*) 'input'/'output' buffers can be used from the activations buffer
#
# PASS:  93%|█████████▎| 86/92 [00:13<00:01,  4.88it/s]
# PASS:  96%|█████████▌| 88/92 [00:13<00:01,  2.88it/s]
#
# Computing AI RT data/code size (target=stm32n6npu)..
#
# PASS:  96%|█████████▌| 88/92 [00:13<00:01,  2.88it/s]
#
#    >>> Shell execution has FAILED (returned code = 1)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    $ arm-none-eabi-gcc -mthumb -mcpu=cortex-m55 -mtune=cortex-m55 -mfloat-abi=hard -Wall -Wextra -Wundef -Wstrict-prototypes -g3 -gdwarf-3 -fmessage-length=0 -fsigned-char -ffunction-sections -fdata-sections -fomit-frame-pointer -falign-functions=16 -Os -DUSE_FULL_LL_DRIVER -DLL_ATON_PLATFORM=LL_ATON_PLAT_SWEMUL -DLL_ATON_OSAL=LL_ATON_OSAL_BARE_METAL -DLL_ATON_RT_MODE=LL_ATON_RT_POLLING -DLL_ATON_SW_FALLBACK -I /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Inc -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton -I /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/Devices/STM32N6XX -c /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    In file included from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_platform.h:378,
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#                     from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton.h:36,
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#                     from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:27:
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/Devices/STM32N6XX/ATON.h:6771:2: warning: #warning "Using default value of ATON_BASE" [-Wcpp]
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#     6771 | #warning "Using default value of ATON_BASE"
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |  ^~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    In file included from /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:25:
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c: In function '__LL_ATON_RT_IrqErr':
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:776:20: warning: format '%u' expects argument of type 'unsigned int', but argument 2 has type 'uint32_t' {aka 'long unsigned int'} [-Wformat=]
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      776 |     LL_ATON_PRINTF("Streaming engine #%u error interrupt: 0x%" PRIx32 "\n", streaming_engine_nr, streng_err);
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~              ~~~~~~~~~~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                                             |
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                                             uint32_t {aka long unsigned int}
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:776:40: note: format string is defined here
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      776 |     LL_ATON_PRINTF("Streaming engine #%u error interrupt: 0x%" PRIx32 "\n", streaming_engine_nr, streng_err);
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                       ~^
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                        |
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                        unsigned int
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                       %lu
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:75: error: expected ')' before 'PRIx64'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                                           ^~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:29:1: note: 'PRIx64' is defined in header '<inttypes.h>'; did you forget to '#include <inttypes.h>'?
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       28 | #include "ll_aton_runtime.h"
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      +++ |+#include <inttypes.h>
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       29 |
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:35: note: to match this '('
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                   ^
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:23: note: in expansion of macro 'LL_ATON_PRINTF'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                       ^~~~~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:38: warning: format '%d' expects a matching 'int' argument [-Wformat=]
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:62: note: format string is defined here
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                             ~^
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                              |
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                              int
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:38: warning: spurious trailing '%' in format [-Wformat=]
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                      ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_util.h:34:36: note: in definition of macro 'LL_ATON_PRINTF'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#       34 | #define LL_ATON_PRINTF(...) printf(__VA_ARGS__)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                    ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:842:3: note: in expansion of macro 'IRQ_ERR_MSG'
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      842 |   IRQ_ERR_MSG(); // just for debug
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |   ^~~~~~~~~~~
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Middlewares/ST/AI/Npu/ll_aton/ll_aton_runtime.c:742:72: note: format string is defined here
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#      742 | #define IRQ_ERR_MSG() LL_ATON_PRINTF("ATON_STD_IRQHandler()@%d: irqs=0x%" PRIx64 "\n", __LINE__, (uint64_t)irqs)
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#          |                                                                        ^
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
#
#    <<<
#
# PASS:  96%|█████████▌| 88/92 [00:18<00:01,  2.88it/s]
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Compilation details
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Compiler version: 1.1.0-31
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Compiler arguments:  -i /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0.onnx --json-quant-file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0_Q.json -g face_recognition.c --load-mdesc /home/vboxuser/STM32Cube/Repository/Packs/STMicroelectronics/X-CUBE-AI/10.1.0/Utilities/configs/stm32n6.mdesc --load-mpool /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/mempools/model2.mpool --save-mpool-file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_recognition/model2.mpool --out-dir-prefix /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/st_ai_ws/neural_art__face_recognition/ -O3 --all-buffers-info --mvei --cache-maintenance --Oalt-sched --native-float --enable-virtual-mem-pools --Omax-ca-pipe 4 --Ocache-opt --Os --enable-epoch-controller --output-info-file c_info.json --network-name face_recognition
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Memory usage information  (input/output buffers are included in activations)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	flexMEM    [0x34000000 - 0x34000000]:          0  B /          0  B  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	cpuRAM1    [0x34080000 - 0x34080000]:          0  B /          0  B  (  0.00 % used) -- weights:          0  B (  0.00 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	cpuRAM2    [0x34100000 - 0x34200000]:      1.000 MB /      1.000 MB  (100.00 % used) -- weights:          0  B (  0.00 % used)  activations:      1.000 MB (100.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM3    [0x34200000 - 0x34270000]:    448.000 kB /    448.000 kB  (100.00 % used) -- weights:          0  B (  0.00 % used)  activations:    448.000 kB (100.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM4    [0x34270000 - 0x342E0000]:    448.000 kB /    448.000 kB  (100.00 % used) -- weights:          0  B (  0.00 % used)  activations:    448.000 kB (100.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM5    [0x342E0000 - 0x34350000]:    448.000 kB /    448.000 kB  (100.00 % used) -- weights:          0  B (  0.00 % used)  activations:    448.000 kB (100.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM6    [0x34350000 - 0x343C0000]:     84.000 kB /    448.000 kB  ( 18.75 % used) -- weights:          0  B (  0.00 % used)  activations:     84.000 kB ( 18.75 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	octoFlash  [0x72000000 - 0x75D00000]:      1.185 MB /     61.000 MB  (  1.94 % used) -- weights:      1.185 MB (  1.94 % used)  activations:          0  B (  0.00 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	hyperRAM   [0x90000000 - 0x91000000]:      1.531 MB /     16.000 MB  (  9.57 % used) -- weights:          0  B (  0.00 % used)  activations:      1.531 MB (  9.57 % used)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Total:                                             5.111 MB                                  -- weights:      1.185 MB                  activations:      3.926 MB
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Used memory ranges
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	cpuRAM2    [0x34100000 - 0x34200000]: 0x34100000-0x34200000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM3    [0x34200000 - 0x34270000]: 0x34200000-0x34270000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM4    [0x34270000 - 0x342E0000]: 0x34270000-0x342E0000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM5    [0x342E0000 - 0x34350000]: 0x342E0000-0x34350000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	npuRAM6    [0x34350000 - 0x343C0000]: 0x34350000-0x34365000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	octoFlash  [0x72000000 - 0x75D00000]: 0x72000000-0x7212F5B0
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# 	hyperRAM   [0x90000000 - 0x91000000]: 0x90000000-0x90188000
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Epochs details
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#    ---------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Total number of epochs: 170 of which 112 implemented in software
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch ID   HW/SW/EC Operation (SW only)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 1       EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 2      -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 3       EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 4      -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 5      -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 6      -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 7       EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 8      -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 9      -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 10     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 11      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 12     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 13     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 14     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 15      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 16     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 17     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 18     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 19      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 20      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 21     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 22     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 23     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 24      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 25     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 26     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 27     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 28      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 29      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 30     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 31     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 32     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 33      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 34     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 35     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 36     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 37      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 38      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 39     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 40     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 41     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 42      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 43     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 44     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 45     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 46      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 47      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 48     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 49     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 50     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 51      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 52     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 53     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 54     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 55      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 56      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 57     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 58     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 59     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 60      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 61     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 62     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 63     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 64      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 65      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 66     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 67     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 68     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 69      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 70     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 71     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 72     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 73      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 74      EC
#
# ...
# epoch 77     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 78      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 79     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 80     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 81     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 82      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 83      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 84     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 85     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 86     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 87      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 88     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 89     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 90     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 91      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 92      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 93     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 94     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 95     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 96      EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 97     -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 98     -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 99     -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 100     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 101     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 102    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 103    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 104    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 105     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 106    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 107    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 108    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 109     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 110     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 111    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 112    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 113    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 114     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 115    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 116    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 117    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 118     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 119     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 120    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 121    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 122    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 123     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 124    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 125    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 126    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 127     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 128     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 129     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 130    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 131    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 132    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 133     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 134    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 135    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 136    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 137     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 138     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 139     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 140    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 141    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 142    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 143     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 144    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 145    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 146    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 147     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 148     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 149     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 150    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 151    -SW-   (       PRelu        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 152    -SW-   (   QuantizeLinear   )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 153     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 154    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 155    -SW-   (        Conv        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 156    -SW-   (        Cast        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 157    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 158    -SW-   (        Conv        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 159    -SW-   (        Cast        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 160    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 161    -SW-   (        Conv        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 162    -SW-   (        Cast        )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 163     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 164     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 165     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 166     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 167     EC
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 168    -SW-   (  DequantizeLinear  )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 169    -SW-   (        Mul         )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# epoch 170    -SW-   (        Add         )
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# ====================================================================================
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  Generated files (6)
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  ----------------------------------------------------------------------------------------------------------------------------------------
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0.onnx
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0_Q.json
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/face_recognition.c
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/face_recognition_atonbuf.xSPI2.raw
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/face_recognition.h
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
#  /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/face_recognition_ecblobs.h
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
#
# Creating txt report file /home/vboxuser/Desktop/Workshop/EdgeAI_Workshop/Exercise 2/stm32_output/face_recognition/face_recognition_generate_report.txt
#
# PASS:  97%|█████████▋| 89/92 [00:18<00:02,  1.05it/s]
# PASS:  99%|█████████▉| 91/92 [00:18<00:00,  1.39it/s]
# PASS: 100%|██████████| 92/92 [00:19<00:00,  1.28it/s]
#
# elapsed time (generate): 21.562s
#
# ✅ MobileFaceNet model conversion completed successfully

# %% [markdown]
# ## Post-processing and File Organization

# %%
import shutil
def organize_output_files(model_name):
    model_output_dir = output_dir / model_name
    model_output_dir.mkdir(exist_ok=True)

    st_ai_output = Path('stm32_output')

    if st_ai_output.exists():
        # Copy header and C files
        patterns = ['*.c', '*.h', '*_ecblobs.h', '*_data.h']

        for pattern in patterns:
            for src_file in st_ai_output.glob(pattern):
                dst_file = model_output_dir / src_file.name
                shutil.copy(src_file, dst_file)
                print(f"Copied {src_file.name} to {model_output_dir}")

        # Handle raw binary file
        binary_files = list(st_ai_output.glob('*/*.raw'))
        if binary_files:
            
            binary_file = binary_files[0]
            print(binary_file)
            bin_output = model_output_dir / f'{model_name}_data.bin'
            print(bin_output)
            hex_output = model_output_dir / f'{model_name}_data.hex'
            print(hex_output)
            shutil.copy(binary_file, bin_output)
            print(f"Copied binary: {binary_file.name} to {bin_output}")

            # Set address
            address_map = {
                'face_detection': '0x71000000',
                'face_recognition': '0x72000000',
            }
            address = address_map.get(model_name, '0x70380000')

            try:
                subprocess.run([
                    'arm-none-eabi-objcopy', '-I', 'binary', str(bin_output),
                    '--change-addresses', address, '-O', 'ihex', str(hex_output)
                ], check=True)
                print(f"Generated HEX file: {hex_output} at address {address}")
            except subprocess.CalledProcessError as e:
                print(f"Warning: HEX generation failed: {e}")
    else:
        print("Warning: st_ai_output directory not found")

    return model_output_dir

# %%
if centerface_success:
    centerface_dir = organize_output_files('face_detection')
    print(f"CenterFace files organized in: {centerface_dir}")

# %%
if mobilefacenet_success:
    mobilefacenet_dir = organize_output_files('face_recognition')
    print(f"MobileFaceNet files organized in: {mobilefacenet_dir}")
# Out:
# stm32_output/face_detection/face_detection_atonbuf.xSPI2.raw
# stm32_output/face_recognition/face_recognition_data.bin
# stm32_output/face_recognition/face_recognition_data.hex
# Copied binary: face_detection_atonbuf.xSPI2.raw to stm32_output/face_recognition/face_recognition_data.bin
# Generated HEX file: stm32_output/face_recognition/face_recognition_data.hex at address 0x72000000
# MobileFaceNet files organized in: stm32_output/face_recognition

# %% [markdown]
# ## Summary and Next Steps

# %%
print("\n" + "="*50)
print("CONVERSION SUMMARY")
print("="*50)

print(f"CenterFace TFLite → STM32: {'✅ Success' if centerface_success else '❌ Failed'}")
print(f"MobileFaceNet ONNX → STM32: {'✅ Success' if mobilefacenet_success else '❌ Failed'}")

print("\nGenerated files are organized in the ./stm32_output directory")
print("\nNext steps:")
print("1. Review the generated network.c and network.h files")
print("2. Integrate the models into your STM32 project")
print("3. Configure memory pools based on the .mpool files")
print("4. Test the models on your target STM32 hardware")

# List generated files
print("\nGenerated files:")
for item in output_dir.rglob('*'):
    if item.is_file():
        print(f"  {item.relative_to(output_dir)}")
# Out:
# ==================================================
# CONVERSION SUMMARY
# ==================================================
# CenterFace TFLite → STM32: ✅ Success
# MobileFaceNet ONNX → STM32: ✅ Success
#
# Generated files are organized in the ./stm32_output directory
#
# Next steps:
# 1. Review the generated network.c and network.h files
# 2. Integrate the models into your STM32 project
# 3. Configure memory pools based on the .mpool files
# 4. Test the models on your target STM32 hardware
#
# Generated files:
#   face_detection/LICENSE.txt
#   face_detection/centerface_OE_3_2_0_Q.json
#   face_detection/face_detection.c
#   face_detection/centerface_OE_3_2_0.onnx
#   face_detection/face_detection_c_info.json
#   face_detection/face_detection.h
#   face_detection/face_detection_atonbuf.xSPI2.raw
#   face_detection/face_detection_generate_report.txt
#   face_detection/face_detection_ecblobs.h
#   face_recognition/LICENSE.txt
#   face_recognition/face_recognition_c_info.json
#   face_recognition/face_recognition.h
#   face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0.onnx
#   face_recognition/face_recognition.c
#   face_recognition/face_recognition_atonbuf.xSPI2.raw
#   face_recognition/face_recognition_generate_report.txt
#   face_recognition/mobilefacenet_real_faces_onnx_OE_3_2_0_Q.json
#   face_recognition/face_recognition_ecblobs.h
